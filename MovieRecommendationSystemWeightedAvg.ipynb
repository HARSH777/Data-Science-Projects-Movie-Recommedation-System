# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits = credits.rename(index = str, columns={'movie_id': 'id'})

# %%
credits.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
mergedf = credits.merge(movies, on='id')

# %%
mergedf.head()
mergeddfCleaned = mergeddf.drop(columns=['crew','genres','cast','homepage','keywords','overview','production_companies','production_countries','release_date','spoken_languages'], axis = 1)

# %%
mergeddfCleaned.head()
# Out:
#        id                                   title_x     budget  \
# 0   19995                                    Avatar  237000000
# 1     285  Pirates of the Caribbean: At World's End  300000000
# 2  206647                                   Spectre  245000000
# 3   49026                     The Dark Knight Rises  250000000
# 4   49529                               John Carter  260000000
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#       revenue  runtime    status  \
# 0  2787965087    162.0  Released
# 1   961000000    169.0  Released
# 2   880674609    148.0  Released
# ...

# %%
v=mergeddfCleaned['vote_count']
r=mergeddfCleaned['vote_average']
c=mergeddfCleaned['vote_average'].mean()
m=mergeddfCleaned['vote_count'].quantile(0.70)
mergeddfCleaned['weighted_average']= (r*v + c*m)/(v+m)

# %%
m
# Out:
# 581.0

# %%
c
# Out:
# 6.092171559442011

# %%
v.head()
# Out:
# 0    11800
# 1     4500
# 2     4466
# 3     9106
# 4     2124
# Name: vote_count, dtype: int64

# %%
r.head()
# Out:
# 0    7.2
# 1    6.9
# 2    6.3
# 3    7.6
# 4    6.1
# Name: vote_average, dtype: float64

# %%
mergeddfCleaned =mergeddfCleaned.sort_values('weighted_average', ascending = False)

# %%
mergeddfCleaned.head()
# Out:
#        id                   title_x     budget original_language  \
# 1881  278  The Shawshank Redemption   25000000                en
# 3337  238             The Godfather    6000000                en
# 662   550                Fight Club   63000000                en
# 3232  680              Pulp Fiction    8000000                en
# 65    155           The Dark Knight  185000000                en
#
#                 original_title  popularity     revenue  runtime    status  \
# 1881  The Shawshank Redemption  136.747729    28341469    142.0  Released
# 3337             The Godfather  143.659698   245066411    175.0  Released
# 662                 Fight Club  146.757391   100853753    139.0  Released
# 3232              Pulp Fiction  121.463076   213928762    154.0  Released
# 65             The Dark Knight  187.322927  1004558444    152.0  Released
#
#                                                 tagline  \
# 1881  Fear can hold you prisoner. Hope can set you f...
# ...

# %%
mergeddfCleaned.sort_values('popularity', ascending = False).head()
# Out:
#          id                  title_x     budget original_language  \
# 546  211672                  Minions   74000000                en
# 95   157336             Interstellar  165000000                en
# 788  293660                 Deadpool   58000000                en
# 94   118340  Guardians of the Galaxy  170000000                en
# 127   76341       Mad Max: Fury Road  150000000                en
#
#               original_title  popularity     revenue  runtime    status  \
# 546                  Minions  875.581305  1156730962     91.0  Released
# 95              Interstellar  724.247784   675120017    169.0  Released
# 788                 Deadpool  514.569956   783112979    108.0  Released
# 94   Guardians of the Galaxy  481.098624   773328629    121.0  Released
# 127       Mad Max: Fury Road  434.278564   378858340    120.0  Released
#
#                                                tagline  \
# 546       Before Gru, they had a history of bad bosses
# ...

# %%
plt.figure(figsize=[5,5])
sns.barplot(y = mergeddfCleaned['title_x'].head(), x = mergeddfCleaned['weighted_average'].head())
plt.xlabel = 'title'
plt.ylabel ='weightedAverage'

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scale = MinMaxScaler()

# %%
mergeddfCleaned[['scaled_weighted_average','scaled_popularity']] = pd.DataFrame(scale.fit_transform(mergeddfCleaned[['weighted_average','popularity']]), columns=['weighted_average', 'popularity'])

# %%
mergeddfCleaned['score'] = mergeddfCleaned['scaled_weighted_average']*0.5 +mergeddfCleaned['scaled_popularity']*0.5

# %%
mergeddfCleaned[['id','title_x','scaled_weighted_average','scaled_popularity','score']].sort_values('score', ascending = False)
# Out:
#           id                    title_x  scaled_weighted_average  \
# 11     10764          Quantum of Solace                 0.906439
# 1071  232672                    Blended                 0.460630
# 29     37724                    Skyfall                 0.851874
# 135     7978                The Wolfman                 0.725217
# 210      415             Batman & Robin                 0.670973
# ...      ...                        ...                      ...
# 4797   67238                     Cavite                 0.102239
# 4800  231617  Signed, Sealed, Delivered                 0.019593
# 4799   72766                  Newlyweds                 0.039279
# 4801  126186           Shanghai Calling                 0.017935
# 4802   25975          My Date with Drew                 0.000000
#
#       scaled_popularity     score
# 11             0.827162  0.866801
# 1071           1.000000  0.730315
# 29             0.549462  0.700668
# 135            0.587690  0.656453
# ...
